# %% [markdown]
# <a href="https://colab.research.google.com/github/lilianabs/ml-algorithms-from-scratch/blob/main/random_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
# Load dataset for testing implementation
data = load_breast_cancer()
X = data.data
y = data.target

# %% [markdown]
# ## Implementation with sklearn DecisionTree

# %%
rows, features = X.shape
print(rows, features)
# Out:
# 569 30

# %%
trees = []
n_trees = 100
n_feats = 20
max_depth = None
min_samples_split = 2

# %%
def fit():
  pass

# %%
def predict():
  pass
